# %%
import pandas as pd

# %%
df = pd.read_excel("data-carte-collections_2023-07-20.xlsx")

# %%
df.head()
# Out:
#    Numéro de notice                     Titre  \
# 0            130081       Violon / E.979.2.39
# 1            130083      Clavecin / E.979.2.4
# 2            130085         Alto / E.979.2.40
# 3            130086  Violoncelle / E.979.2.41
# 4            130088         Alto / E.979.2.43
#
#                           Facteur ou auteur           Type d'objet  \
# 0  Lejeune, François (vers 1720/1724-1785)  Instrument de musique
# 1              Collesse, Joseph (1717-1776)  Instrument de musique
# 2  Lejeune, François (vers 1720/1724-1785)  Instrument de musique
# 3  Lejeune, François (vers 1720/1724-1785)  Instrument de musique
# 4               Fleury, Benoît (1719-1792)  Instrument de musique
#
#      Instrument niveau 1 Instrument niveau 2 Instrument niveau 3  \
# 0   Instrument à cordes             Violons              Violon
# 1  Instrument à clavier           Clavecins            Clavecin
# 2   Instrument à cordes               Altos                Alto
# ...

# %%
#df['URL Enregistrement'] = df['URL Enregistrement'].fillna("https://mimo-international.com/media/CM/AUDIO/CM0130201eCOAU900006101_04.mp3")

# %%
df.to_csv("data-carte-collections_2023-07-20.csv",index=False)
